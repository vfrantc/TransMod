# %% [markdown]
# <a href="https://colab.research.google.com/github/vfrantc/TransMod/blob/main/transweather_quat_and_trans_sharpening_alpha_root.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Jun  2 15:28:38 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    44W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install kornia
# !pip install kornia[x]  # to get the training API!
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 512 kB 5.1 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 114 kB 5.1 MB/s
# ...

# %%
# !git clone https://github.com/vfrantc/TransMod.git
# Out:
# Cloning into 'TransMod'...
# remote: Enumerating objects: 396, done.
# remote: Counting objects: 100% (132/132), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 396 (delta 85), reused 74 (delta 44), pack-reused 264
# Receiving objects: 100% (396/396), 11.10 MiB | 23.94 MiB/s, done.
# Resolving deltas: 100% (206/206), done.

# %%
# %cd TransMod
# Out:
# /content/TransMod

# %%
# !git pull
# Out:
# Already up to date.

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# !cp drive/MyDrive/derain/data.tar.gz .

# %%
# !tar xzvf data.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# data/test/Snow100K-L/input/winter_tree_03228.jpg
# data/test/Snow100K-L/input/winter_japan_06068.jpg
# data/test/Snow100K-L/input/winter_japan_06121.jpg
# data/test/Snow100K-L/input/winter_japan_06138.jpg
# data/test/Snow100K-L/input/winter_tree_02854.jpg
# data/test/Snow100K-L/input/winter_park_18248.jpg
# data/test/Snow100K-L/input/winter_japan_05792.jpg
# data/test/Snow100K-L/input/winter_tree_02097.jpg
# data/test/Snow100K-L/input/winter_tree_02162.jpg
# data/test/Snow100K-L/input/winter_road_00337.jpg
# data/test/Snow100K-L/input/winter_road_00523.jpg
# data/test/Snow100K-L/input/winter_road_04022.jpg
# data/test/Snow100K-L/input/winter_park_17844.jpg
# data/test/Snow100K-L/input/winter_japan_05662.jpg
# data/test/Snow100K-L/input/winter_park_09213.jpg
# data/test/Snow100K-L/input/winter_park_09347.jpg
# data/test/Snow100K-L/input/winter_japan_07856.jpg
# data/test/Snow100K-L/input/winter_japan_08081.jpg
# ...

# %%
# !mkdir ./training_log

# %%
# !pip install thop
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !cp drive/MyDrive/derain/Transweather6_25.zip .
# !unzip Transweather6_25.zip
# !cp Transweather6_25.zip drive/MyDrive/derain

# %%
# !python3 train.py  -train_batch_size 32 -exp_name Transweather -epoch_start 25 -num_epochs 250 -my_model=5
# Out:
# Seed:	19
# --- Hyper-parameters for training ---
# learning_rate: 0.0002
# crop_size: [256, 256]
# train_batch_size: 32
# val_batch_size: 1
# lambda_loss: 0.04
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100% 528M/528M [00:04<00:00, 127MB/s]
# --- weight loaded ---
# Rain Drop old_val_psnr: 60.27, old_val_ssim: 0.9971
# Learning rate sets to 0.0002.
# Epoch: 25, Iteration: 0
# Epoch: 25, Iteration: 100
# Epoch: 25, Iteration: 200
# Epoch: 25, Iteration: 300
# Epoch: 25, Iteration: 400
# Epoch: 25, Iteration: 500
# Rain Drop
# (153s) Epoch [26/250], Train_PSNR:17.63, Val_PSNR:61.31, Val_SSIM:0.9978
# model saved
# Learning rate sets to 0.0002.
# Epoch: 26, Iteration: 0
# Epoch: 26, Iteration: 100
# Epoch: 26, Iteration: 200
# Epoch: 26, Iteration: 300
# Epoch: 26, Iteration: 400
# Epoch: 26, Iteration: 500
# Rain Drop
# (152s) Epoch [27/250], Train_PSNR:18.01, Val_PSNR:61.14, Val_SSIM:0.9976
# ...

# %% [markdown]
# # TODO: Compress and save the model

# %%
# !zip -r Transweather6_250.zip ./Transweather/
# !cp Transweather6_250.zip drive/MyDrive/derain
# Out:
#   adding: Transweather/ (stored 0%)
#   adding: Transweather/latest (deflated 7%)
#   adding: Transweather/best (deflated 7%)

# %% [markdown]
# # Testing

# %%
# !cp -r drive/MyDrive/derain/Transweather6_25.zip .
# !unzip Transweather6_25.zip
# Out:
# Archive:  Transweather6_25.zip
#    creating: Transweather/
#   inflating: Transweather/latest
#   inflating: Transweather/best

# %%
# !cp -r drive/MyDrive/derain/Transweather6_250.zip .
# !unzip Transweather6_250.zip
# Out:
# Archive:  Transweather6_250.zip
# replace Transweather/latest? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#!cp ./Transweather/latest ./Transweather/best

# %%
# !python test_snow100k.py -exp_name=./Transweather  -my_model=5
# Out:
# Streaming output truncated to the last 5000 lines.
# winter_park_05900.jpg
# winter_weather_02497.jpg
# city_read_06493.jpg
# winter_park_05294.jpg
# crossing_05711.jpg
# parking_lot_09299.jpg
# city_read_00725.jpg
# winter_park_09928.jpg
# parking_lot_03246.jpg
# winter__street_00108.jpg
# crossing_01416.jpg
# school_night_07681.jpg
# beautiful_smile_02207.jpg
# beautiful_smile_03230.jpg
# winter_tree_07673.jpg
# sidewalk winter -grayscale -gray_06837.jpg
# city_read_03394.jpg
# winter_new_york_00655.jpg
# city_read_02011.jpg
# parking_lot_14093.jpg
# winter__street_05384.jpg
# city_read_05712.jpg
# winter_new_york_06325.jpg
# parking_lot_08170.jpg
# winter_japan_17430.jpg
# city_read_04730.jpg
# winter_park_07659.jpg
# city_read_02003.jpg
# city_read_20335.jpg
# winter_park_01149.jpg
# city_read_12125.jpg
# winter_park_16245.jpg
# parking_lot_07117.jpg
# city_read_08009.jpg
# beautiful_smile_00416.jpg
# winter_tree_04886.jpg
# winter_japan_11816.jpg
# winter_road_00482.jpg
# ...

# %%
# !python ./test_raindrop.py -exp_name=./Transweather -my_model=5
# Out:
# Seed:	19
# Traceback (most recent call last):
#   File "./test_raindrop.py", line 57, in <module>
#     val_data_loader = DataLoader(ValData(val_data_dir,val_filename), batch_size=val_batch_size, shuffle=False, num_workers=8)
#   File "/content/TransMod/val_data_functions.py", line 11, in __init__
#     with open(val_list) as f:
# FileNotFoundError: [Errno 2] No such file or directory: './data/test/raindroptest1a.txt'

# %%
# !python ./test_test1.py -exp_name=./Transweather -my_model=5
# Out:
# Seed:	19
# cuda
# --- Testing starts! ---
# im_0307_s95_a04.png
# im_0302_s100_a06.png
# im_0321_s95_a04.png
# im_0315_s100_a04.png
# im_0308_s85_a06.png
# im_0312_s85_a05.png
# im_0330_s100_a06.png
# im_0314_s100_a06.png
# im_0338_s100_a05.png
# im_0347_s85_a04.png
# im_0309_s85_a06.png
# im_0332_s100_a04.png
# im_0314_s100_a05.png
# im_0336_s85_a05.png
# im_0310_s85_a04.png
# im_0317_s95_a06.png
# im_0328_s95_a04.png
# im_0347_s80_a05.png
# im_0320_s90_a04.png
# im_0314_s85_a04.png
# im_0339_s85_a06.png
# im_0301_s100_a04.png
# im_0329_s85_a05.png
# im_0331_s100_a05.png
# im_0307_s100_a04.png
# im_0338_s100_a06.png
# im_0306_s90_a05.png
# im_0304_s100_a06.png
# im_0302_s95_a05.png
# im_0343_s85_a05.png
# im_0329_s80_a04.png
# im_0312_s80_a05.png
# im_0311_s90_a05.png
# im_0325_s80_a05.png
# im_0348_s100_a05.png
# im_0337_s85_a06.png
# im_0346_s80_a05.png
# im_0310_s80_a04.png
# im_0318_s80_a06.png
# im_0332_s80_a04.png
# im_0338_s90_a04.png
# im_0331_s100_a06.png
# ...

# %%
# !zip -r model6_250.zip ./results/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: results/snowtest100k/Transweather/winter_park_12108.jpg (deflated 1%)
#   adding: results/snowtest100k/Transweather/beautiful_smile_03720.jpg (deflated 1%)
#   adding: results/snowtest100k/Transweather/city_read_15656.jpg (deflated 1%)
#   adding: results/snowtest100k/Transweather/winter_park_15257.jpg (deflated 1%)
#   adding: results/snowtest100k/Transweather/parking_lot_00045.jpg (deflated 1%)
#   adding: results/snowtest100k/Transweather/city_read_16219.jpg (deflated 0%)
#   adding: results/snowtest100k/Transweather/winter_japan_14244.jpg (deflated 1%)
#   adding: results/snowtest100k/Transweather/parking_lot_04586.jpg (deflated 1%)
#   adding: results/snowtest100k/Transweather/winter__street_03214.jpg (deflated 1%)
#   adding: results/snowtest100k/Transweather/winter intersection -snow_01734.jpg (deflated 1%)
#   adding: results/snowtest100k/Transweather/crossing_03854.jpg (deflated 1%)
# ...

# %%
# !cp model6_250.zip drive/MyDrive/derain/
