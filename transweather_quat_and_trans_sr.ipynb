# %% [markdown]
# <a href="https://colab.research.google.com/github/vfrantc/TransMod/blob/main/transweather_quat_and_trans_sr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue May 17 21:26:09 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/vfrantc/TransMod.git

# %%
# %cd TransMod
# Out:
# /content/TransMod

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# !cp drive/MyDrive/derain/data.tar.gz .

# %%
# !tar xzvf data.tar.gz
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# data/test/Snow100K-L/input/winter_tree_03228.jpg
# data/test/Snow100K-L/input/winter_japan_06068.jpg
# data/test/Snow100K-L/input/winter_japan_06121.jpg
# data/test/Snow100K-L/input/winter_japan_06138.jpg
# data/test/Snow100K-L/input/winter_tree_02854.jpg
# data/test/Snow100K-L/input/winter_park_18248.jpg
# data/test/Snow100K-L/input/winter_japan_05792.jpg
# data/test/Snow100K-L/input/winter_tree_02097.jpg
# data/test/Snow100K-L/input/winter_tree_02162.jpg
# data/test/Snow100K-L/input/winter_road_00337.jpg
# data/test/Snow100K-L/input/winter_road_00523.jpg
# data/test/Snow100K-L/input/winter_road_04022.jpg
# data/test/Snow100K-L/input/winter_park_17844.jpg
# data/test/Snow100K-L/input/winter_japan_05662.jpg
# data/test/Snow100K-L/input/winter_park_09213.jpg
# data/test/Snow100K-L/input/winter_park_09347.jpg
# data/test/Snow100K-L/input/winter_japan_07856.jpg
# data/test/Snow100K-L/input/winter_japan_08081.jpg
# ...

# %%
# !mkdir ./training_log

# %%
# !pip install thop

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !python3 train_sr.py  -train_batch_size 16 -exp_name Transweather -epoch_start 0 -num_epochs 100
# Out:
# Seed:	19
# --- Hyper-parameters for training ---
# learning_rate: 0.0002
# crop_size: [256, 256]
# train_batch_size: 16
# val_batch_size: 1
# lambda_loss: 0.04
# --- no weight loaded ---
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Rain Drop old_val_psnr: 11.54, old_val_ssim: 0.0038
# Learning rate sets to 0.0002.
# Epoch: 0, Iteration: 0
# Epoch: 0, Iteration: 100
# Epoch: 0, Iteration: 200
# Epoch: 0, Iteration: 300
# Epoch: 0, Iteration: 400
# Epoch: 0, Iteration: 500
# Epoch: 0, Iteration: 600
# Epoch: 0, Iteration: 700
# Epoch: 0, Iteration: 800
# ...

# %% [markdown]
# # TODO: Compress and save the model

# %%
# !zip -r Transweather_orig_no_inter_linear_quat_trans_sr100.zip ./Transweather/
# !cp Transweather_orig_no_inter_linear_quat_trans_sr100.zip drive/MyDrive/derain
# Out:
#   adding: Transweather/ (stored 0%)

# %% [markdown]
# # Testing

# %%
#!cp drive/MyDrive/derain/Transweather_orig_no_inter_linear_quat_trans_sr100.zip .
#!unzip Transweather_orig_no_inter_linear_quat_trans_sr100.zip

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/vfrantc/TransMod
#    98245b3..4ee51ee  main       -> origin/main
# Updating 98245b3..4ee51ee
# Fast-forward
#  test_snow100k_sr.py | 13 -------------
#  1 file changed, 13 deletions(-)

# %%
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !python test_snow100k_sr.py -exp_name=./Transweather
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# winter_park_05900.jpg
# winter_weather_02497.jpg
# city_read_06493.jpg
# winter_park_05294.jpg
# crossing_05711.jpg
# parking_lot_09299.jpg
# city_read_00725.jpg
# winter_park_09928.jpg
# parking_lot_03246.jpg
# winter__street_00108.jpg
# crossing_01416.jpg
# school_night_07681.jpg
# beautiful_smile_02207.jpg
# beautiful_smile_03230.jpg
# winter_tree_07673.jpg
# sidewalk winter -grayscale -gray_06837.jpg
# city_read_03394.jpg
# winter_new_york_00655.jpg
# city_read_02011.jpg
# parking_lot_14093.jpg
# winter__street_05384.jpg
# city_read_05712.jpg
# winter_new_york_06325.jpg
# parking_lot_08170.jpg
# winter_japan_17430.jpg
# city_read_04730.jpg
# winter_park_07659.jpg
# city_read_02003.jpg
# city_read_20335.jpg
# winter_park_01149.jpg
# city_read_12125.jpg
# winter_park_16245.jpg
# parking_lot_07117.jpg
# city_read_08009.jpg
# beautiful_smile_00416.jpg
# winter_tree_04886.jpg
# winter_japan_11816.jpg
# ...

# %%
# !python ./test_raindropa_sr.py -exp_name=./Transweather
# Out:
# Seed:	19
# cuda
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# --- Testing starts! ---
# 23_rain.png
# 25_rain.png
# 20_rain.png
# 4_rain.png
# 50_rain.png
# 14_rain.png
# 41_rain.png
# 24_rain.png
# 22_rain.png
# 37_rain.png
# 35_rain.png
# 52_rain.png
# 54_rain.png
# 21_rain.png
# 0_rain.png
# 38_rain.png
# 1_rain.png
# 6_rain.png
# 56_rain.png
# 39_rain.png
# 43_rain.png
# 17_rain.png
# 30_rain.png
# 45_rain.png
# 28_rain.png
# 27_rain.png
# 36_rain.png
# 42_rain.png
# 13_rain.png
# 2_rain.png
# 47_rain.png
# 12_rain.png
# 49_rain.png
# 18_rain.png
# 31_rain.png
# ...

# %%
# !python ./test_test1_sr.py -exp_name=./Transweather

# %%
# !zip -r quaternion_and_trans_sr100.zip ./results/
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#   adding: results/snowtest100k/Transweather/parking_lot_14287.jpg (deflated 1%)
#   adding: results/snowtest100k/Transweather/winter_japan_00457.jpg (deflated 1%)
#   adding: results/snowtest100k/Transweather/beautiful_smile_03909.jpg (deflated 0%)
#   adding: results/snowtest100k/Transweather/winter_japan_04115.jpg (deflated 0%)
#   adding: results/snowtest100k/Transweather/winter_japan_15410.jpg (deflated 0%)
#   adding: results/snowtest100k/Transweather/city_read_18808.jpg (deflated 0%)
#   adding: results/snowtest100k/Transweather/winter_park_17704.jpg (deflated 0%)
#   adding: results/snowtest100k/Transweather/sidewalk winter -grayscale -gray_07743.jpg (deflated 0%)
#   adding: results/snowtest100k/Transweather/winter_park_13325.jpg (deflated 0%)
#   adding: results/snowtest100k/Transweather/city_read_02912.jpg (deflated 0%)
#   adding: results/snowtest100k/Transweather/winter__street_01620.jpg (deflated 0%)
# ...

# %%
# !cp quaternion_and_trans_sr100.zip drive/MyDrive/derain/
