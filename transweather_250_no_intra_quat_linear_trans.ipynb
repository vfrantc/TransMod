# %% [markdown]
# <a href="https://colab.research.google.com/github/vfrantc/TransMod/blob/main/transweather_250_no_intra_quat_linear_trans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri May 13 08:09:43 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    23W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/vfrantc/TransMod.git
# Out:
# Cloning into 'TransMod'...
# remote: Enumerating objects: 243, done.
# remote: Counting objects: 100% (243/243), done.
# remote: Compressing objects: 100% (188/188), done.
# remote: Total 243 (delta 106), reused 170 (delta 46), pack-reused 0
# Receiving objects: 100% (243/243), 10.77 MiB | 14.87 MiB/s, done.
# Resolving deltas: 100% (106/106), done.

# %%
# %cd TransMod
# Out:
# /content/TransMod

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# !cp drive/MyDrive/derain/data.tar.gz .

# %%
# !tar xzvf data.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# data/train/allweather/input/crossing_01395.jpg
# data/train/allweather/input/city_read_01885.jpg
# data/train/allweather/input/im_0459_s90_a06.png
# data/train/allweather/input/beautiful_smile_01004.jpg
# data/train/allweather/input/im_0272_s80_a04.png
# data/train/allweather/input/sidewalk winter -grayscale -gray_02837.jpg
# data/train/allweather/input/winter_house_04041.jpg
# data/train/allweather/input/im_0467_s90_a04.png
# data/train/allweather/input/im_0066_s80_a06.png
# data/train/allweather/input/im_0043_s80_a06.png
# data/train/allweather/input/winter_park_00286.jpg
# data/train/allweather/input/im_0215_s80_a04.png
# data/train/allweather/input/crossing_03552.jpg
# data/train/allweather/input/city_read_04374.jpg
# data/train/allweather/input/winter_building_03488.jpg
# data/train/allweather/input/im_0016_s100_a04.png
# data/train/allweather/input/winter_new_york_00606.jpg
# data/train/allweather/input/im_0119_s90_a04.png
# ...

# %%
# !mkdir ./training_log

# %%
# !git pull

# %%
# !pip install thop

# %%
# !python3 train.py  -train_batch_size 32 -exp_name Transweather -epoch_start 0 -num_epochs 100 -my_model=3
# Out:
# Seed:	19
# --- Hyper-parameters for training ---
# learning_rate: 0.0002
# crop_size: [256, 256]
# train_batch_size: 32
# val_batch_size: 1
# lambda_loss: 0.04
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100% 528M/528M [00:02<00:00, 245MB/s]
# --- no weight loaded ---
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Rain Drop old_val_psnr: 12.83, old_val_ssim: 0.0423
# Learning rate sets to 0.0002.
# Epoch: 0, Iteration: 0
# Epoch: 0, Iteration: 100
# Epoch: 0, Iteration: 200
# ...

# %% [markdown]
# # TODO: Compress and save the model

# %%
# !zip -r Transweather_orig_no_inter_linear_quat.zip ./Transweather/
# !cp Transweather_orig_no_inter_linear_quat.zip drive/MyDrive/derain
